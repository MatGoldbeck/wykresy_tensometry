# %%
# import pandas as pd
import rainflow
filedemo='RejestratorCisnien11_05_23_12_43_07   c.csv'
#coldemo=['timestamp','delta']

# %% [markdown]
# from math import sin, cos
#
# time = [4.0 * i / 200 for i in range(200 + 1)]
# signal = [0.2 + 0.5 * sin(t) + 0.2 * cos(10*t) + 0.2 * sin(4*t) for t in time]
# signal

# %%
import csv
list2 = []
ala = open('RejestratorCisnien11_05_23_12_43_07   c.csv',mode='r')
print(ala)
#    for row in f:
#        list2.append(row[])
#list2
# Out:
# <_io.TextIOWrapper name='RejestratorCisnien11_05_23_12_43_07   c.csv' mode='r' encoding='cp1250'>

# %%
import csv
first_column = []
with open('RejestratorCisnien11_05_23_12_43_07   c.csv') as f
    for row in f:
        first_column.append(row[0])
data = list(csv.reader(file, delimiter=","))
file.close()
data.pop(0)
data
# Out:
# [['1683807387.027055',
#   '999999.000000',
#   '0.002000',
#   '0.013775',
#   '-0.000009',
#   '0.000241',
#   '0.000300',
#   '0.000424',
#   '-0.025008',
#   '-0.025004',
#   '-0.025038',
#   '-0.025014',
#   '0.000375'],
#  ['1683807387.027055',
#   '1000000.000000',
#   '0.002000',
#   '0.013781',
#   '-0.000001',
#   '0.000240',
#   '0.000304',
#   '0.000421',
#   '-0.025008',
#   '-0.025004',
#   '-0.025038',
#   '-0.025014',
#   '0.000377'],
#  ['1683807387.027055',
#   '1000001.000000',
#   '0.002000',
#   '0.013780',
#   '0.000002',
#   '0.000239',
#   '0.000299',
#   '0.000420',
#   '-0.025008',
#   '-0.025004',
#   '-0.025038',
#   '-0.025014',
#   '0.000377'],
#  ['1683807387.027055',
#   '1000002.000000',
#   '0.002000',
#   '0.013778',
#   '0.000000',
#   '0.000240',
#   '0.000307',
#   '0.000420',
#   '-0.025008',
#   '-0.025004',
#   '-0.025038',
#   '-0.025014',
#   '0.000375'],
#  ['1683807387.027055',
#   '1000003.000000',
#   '0.002000',
#   '0.013786',
# ...

# %%
from math import sin, cos

time = [4.0 * i / 200 for i in range(200 + 1)]
signal = [0.2 + 0.5 * sin(t) + 0.2 * cos(10*t) + 0.2 * sin(4*t) for t in time]

# %%
df=pd.read_csv(filedemo,usecols=[1])
df.drop(df.index[0:1000], inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MGOLAB~1.000\AppData\Local\Temp/ipykernel_5340/604037607.py in <module>
# ----> 1 df=pd.read_csv(filedemo,usecols=[1])
#       2 df.drop(df.index[0:1000], inplace=True)
#       3 df
#
# NameError: name 'pd' is not defined

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
df.values.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MGOLAB~1.000\AppData\Local\Temp/ipykernel_5340/3526949163.py in <module>
# ----> 1 df.values.tolist()
#
# NameError: name 'df' is not defined

# %%
df.head
# Out:
# <bound method NDFrame.head of                nr
# 1000    1000999.0
# 1001    1001000.0
# 1002    1001001.0
# 1003    1001002.0
# 1004    1001003.0
# ...           ...
# 111933  1111932.0
# 111934  1111933.0
# 111935  1111934.0
# 111936  1111935.0
# 111937  1111936.0
#
# [110938 rows x 1 columns]>

# %%
rainflow.count_cycles(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\MGOLAB~1.000\AppData\Local\Temp/ipykernel_13196/2774520640.py in <module>
# ----> 1 rainflow.count_cycles(data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\rainflow.py in count_cycles(series, ndigits, nbins, binsize)
#     165
#     166     else:
# --> 167         for rng, count in cycles:
#     168             counts[rng] += count
#     169
#
# C:\ProgramData\Anaconda3\lib\site-packages\rainflow.py in <genexpr>(.0)
#     141
#     142     counts = defaultdict(float)
# --> 143     cycles = (
#     144         (rng, count)
#     145         for rng, mean, count, i_start, i_end in extract_cycles(series)
#
# C:\ProgramData\Anaconda3\lib\site-packages\rainflow.py in extract_cycles(series)
#      81         return rng, mean, count, i1, i2
#      82
# ---> 83     for point in reversals(series):
# ...
