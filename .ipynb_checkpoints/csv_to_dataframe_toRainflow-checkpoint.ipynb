# %%
import pandas as pd
import rainflow
import matplotlib.pyplot as plt
filedemo='RejestratorCisnien11_05_23_12_43_07   c.csv'
#coldemo=['timestamp','delta']

# %%
df=pd.read_csv(filedemo)
df.drop(df.index[0:1000], inplace=True)
df
# Out:
#            timestamp         nr  delta      E-IL      F-II     G-bok  \
# 1000    1.683807e+09  1000999.0  0.002  0.014022  0.000003  0.000242
# 1001    1.683807e+09  1001000.0  0.002  0.014017  0.000001  0.000244
# 1002    1.683807e+09  1001001.0  0.002  0.014016  0.000000  0.000243
# 1003    1.683807e+09  1001002.0  0.002  0.014020 -0.000000  0.000243
# 1004    1.683807e+09  1001003.0  0.002  0.014022 -0.000002  0.000244
# ...              ...        ...    ...       ...       ...       ...
# 111933  1.683808e+09  1111932.0  0.002  0.013399 -0.000001  0.000201
# 111934  1.683808e+09  1111933.0  0.002  0.013410 -0.000001  0.000218
# 111935  1.683808e+09  1111934.0  0.002  0.013399 -0.000001  0.000235
# 111936  1.683808e+09  1111935.0  0.002  0.013402 -0.000002  0.000207
# 111937  1.683808e+09  1111936.0  0.002  0.013400 -0.000006  0.000225
#
#           H-gora   I-zebro  J-silownik_dol  K-silownik_gora       No1  \
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
product = df['G-bok'].values.tolist()
product
# Out:
# [0.000242,
#  0.000244,
#  0.000243,
#  0.000243,
#  0.000244,
#  0.000243,
#  0.000243,
#  0.000243,
#  0.000243,
#  0.000244,
#  0.000242,
#  0.00024,
#  0.000242,
#  0.000244,
#  0.000243,
#  0.000243,
#  0.000245,
#  0.000244,
#  0.000246,
#  0.000243,
#  0.000242,
#  0.000244,
#  0.000243,
#  0.000242,
#  0.000241,
#  0.000241,
#  0.000243,
#  0.000241,
#  0.000238,
#  0.000244,
#  0.000239,
#  0.000239,
#  0.000238,
#  0.000238,
#  0.000242,
#  0.000237,
#  0.000239,
#  0.000244,
#  0.000241,
#  0.000244,
#  0.000242,
#  0.000243,
#  0.000243,
#  0.00024,
#  0.000242,
#  0.000246,
#  0.000243,
#  0.000241,
#  0.000242,
#  0.000242,
#  0.000243,
#  0.000241,
#  0.000243,
#  0.00024,
#  0.000243,
#  0.000242,
#  0.00024,
#  0.000242,
#  0.000241,
#  0.000244,
#  0.000244,
#  0.000242,
#  0.000243,
#  0.000241,
#  0.000242,
#  0.000241,
#  0.000244,
#  0.000246,
#  0.000245,
#  0.000243,
#  0.000245,
#  0.000243,
#  0.000243,
#  0.000241,
#  0.000243,
#  0.00024,
#  0.000244,
# ...

# %%
rnf = rainflow.count_cycles(product)
rnf
# Out:
# [(9.9999999999997e-07, 738.0),
#  (9.999999999999972e-07, 347.0),
#  (1.0000000000000243e-06, 949.0),
#  (1.9999999999999944e-06, 1547.5),
#  (2.0000000000000215e-06, 68.0),
#  (2.0000000000000486e-06, 154.0),
#  (2.9999999999999645e-06, 399.0),
#  (2.9999999999999916e-06, 248.0),
#  (3.0000000000000187e-06, 907.0),
#  (3.999999999999989e-06, 946.5),
#  (4.000000000000016e-06, 124.0),
#  (4.000000000000043e-06, 223.0),
#  (4.999999999999959e-06, 151.0),
#  (4.999999999999986e-06, 134.0),
#  (5.000000000000013e-06, 732.0),
#  (5.999999999999983e-06, 534.0),
#  (6.00000000000001e-06, 198.5),
#  (6.000000000000037e-06, 200.0),
#  (6.999999999999953e-06, 63.0),
#  (6.99999999999998e-06, 91.0),
#  (7.0000000000000075e-06, 652.0),
#  (7.999999999999978e-06, 320.0),
#  (8.000000000000005e-06, 201.0),
#  (8.000000000000032e-06, 204.0),
#  (8.999999999999948e-06, 14.0),
#  (8.999999999999975e-06, 48.0),
#  (9.000000000000002e-06, 680.0),
#  (9.000000000000029e-06, 26.5),
# ...

# %%
print(type(rnf))
# Out:
# <class 'list'>

# %%
x_val = [x[0] for x in rnf]
y_val = [x[1] for x in rnf]

#print(x_val)
plt.plot(x_val,y_val)
plt.plot(x_val,y_val,'or')
plt.show()

# %%
fig, ax = plt.subplots(1,1) # gets a handle for the AxesSubplot object
x1 = ax.plot(x_val, y_val,)
x2 = ax.plot(x_val, y_val, 'b-')
#ax.set_yscale('log')
ax.set_xscale('log')
plt.title('Histogram zarejestrowanego obciążenia')
plt.xlabel('napreżenia [MPa]')
plt.ylabel('libcza cykli')
fig.show()
# Out:
# C:\Users\MGOLAB~1.000\AppData\Local\Temp/ipykernel_2264/2043269064.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
fig, ax = plt.subplots(1,1) # gets a handle for the AxesSubplot object
x = [300, 400, 500, 2000, 10, 22, 77, 78]

plt.hist(product, 10)
ax.set_yscale('log')
plt.title('Histogram zarejestrowanych wartości szczytowych obciążenia')
plt.xlabel('napreżenia [MPa]')
plt.xticks(np.arange(-0.005, 0.005, 0.001))
plt.ylabel('libcza cykli')
plt.show()

plt.hist(product, 10, color = "red")
ax.set_yscale('log')
plt.title('Histogram zarejestrowanych amplitud naprężeń (delta sigma)')
plt.xlabel('napreżenia [MPa]')
plt.xticks(np.arange(-0.005, 0.005, 0.001))
plt.ylabel('libcza cykli')
plt.show()

plt.hist(product, 10, color = "green")
ax.set_yscale('log')
plt.title('Histogram zarejestrowanych amplitud naprężeń (delta sigma)')
plt.xlabel('napreżenia [MPa]')
plt.xticks(np.arange(-0.005, 0.005, 0.001))
plt.ylabel('libcza cykli')
plt.show()
